# %%
import numpy as np
import matplotlib.pyplot as plt
from sklearn.metrics import mean_absolute_error, mean_squared_error, r2_score

def create_data(num_samples, shuffle=False):
    x_values = np.linspace(-1, 1, num_samples)
    y_values = 0.2 * x_values ** 4 + 2 * x_values ** 3 + 0.1 * x_values ** 2 + 10
    data = np.column_stack((x_values, y_values))
    if shuffle:
        np.random.shuffle(data)
    return data

def train_val_test_split(data, train_ratio=0.6, val_ratio=0.2, test_ratio=0.2):
    assert train_ratio + val_ratio + test_ratio == 1.0, 'Ratios must sum to 1.0'
  
    num_train = int(train_ratio * len(data))
    num_val = int(val_ratio * len(data))
    num_test = len(data) - num_train - num_val

    train_data = data[:num_train]
    val_data = data[num_train:num_train+num_val]
    test_data = data[num_train+num_val:]

    return train_data, val_data, test_data

def scale_data(data):
    min_vals = np.min(data, axis=0)
    max_vals = np.max(data, axis=0)
    min_vals_minus = min_vals - 1
    apple = data - (min_vals_minus)
    apple1 = max_vals - (min_vals_minus)
    return (apple + 1) / (apple1 + 1)

def calculate_regression_metrics(actual, predicted):
    mae = mean_absolute_error(actual, predicted)
    mse = mean_squared_error(actual, predicted)
    rmse = np.sqrt(mse)
    r2 = r2_score(actual, predicted)
    return mae, mse, rmse, r2

# Generate shuffled and unshuffled data
num_samples = 30000
shuffled_data = create_data(num_samples, shuffle=True)
unshuffled_data = create_data(num_samples, shuffle=False)

# Split shuffled and unshuffled data into train, validation, and test sets
train_data, val_data, test_data = train_val_test_split(shuffled_data)
train_data2, val_data2, test_data2 = train_val_test_split(unshuffled_data)

# Scale the shuffled data
scaled_data = scale_data(shuffled_data)

# Plot shuffled, unshuffled, and scaled data
for data, title in zip([shuffled_data, unshuffled_data, scaled_data], ['Shuffled Data', 'Unshuffled Data', 'Scaled Data']):
    plt.scatter(data[:, 0], data[:, 1], s=0.1)
    plt.xlabel('x')
    plt.ylabel('y')
    plt.title(title)
    plt.show()

# Example usage of calculate_regression_metrics function
actual = [1, 2, 3, 4, 5]
predicted = [1.5, 2.5, 3.5, 4.5, 5.5]
mae, mse, rmse, r2 = calculate_regression_metrics(actual, predicted)
print(f"MAE: {mae:.4f}")
print(f"MSE: {mse:.4f}")
print(f"RMSE: {rmse:.4f}")
print(f"R^2: {r2:.4f}")
print("R2 score: {:.4f}".format(r2))
# Out:
# MAE: 0.5000
# MSE: 0.2500
# RMSE: 0.5000
# R^2: 0.8750
# R2 score: 0.8750

# %% [markdown]
# The code above is Questions 1 - 4

# %%
import numpy as np
import matplotlib.pyplot as plt
import tensorflow as tf
from tensorflow import keras
from sklearn.metrics import mean_absolute_error, mean_squared_error, r2_score
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import MinMaxScaler
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense

def create_data(num_samples, shuffle=False):
    x_values = np.linspace(-1, 1, num_samples)
    y_values = 0.2*x_values**4 + 2*x_values**3 + 0.1*x_values**2 + 10
    data = np.column_stack((x_values, y_values))
    if shuffle:
        np.random.shuffle(data)
    return data

def train_val_test_split(data, train_ratio=0.6, val_ratio=0.2, test_ratio=0.2):
    assert train_ratio + val_ratio + test_ratio == 1.0, 'Ratios must sum to 1.0'

    num_train = int(train_ratio * len(data))
    train_data = data[:num_train]
    remaining_data = data[num_train:]

    num_val = int(val_ratio / (val_ratio + test_ratio) * len(remaining_data))
    val_data = remaining_data[:num_val]
    test_data = remaining_data[num_val:]

    return train_data, val_data, test_data

def scale_data(data):
    apple2 = data - np.min(data, axis=0) - 1
    apple3 = np.max(data, axis=0) - np.min(data, axis=0) - 1
    return (apple2 + 1) / (apple3 + 1)
#-----------------------------Case 1----------------------------------------
# Setup
num_samples = 30000
shuffled_data = create_data(num_samples, shuffle=True)
unshuffled_data = create_data(num_samples, shuffle=False)
train_data, val_data, test_data = train_val_test_split(shuffled_data, train_ratio=0.3, val_ratio=0.2, test_ratio=0.5)
train_data2, val_data2, test_data2 = train_val_test_split(unshuffled_data, train_ratio=0.3, val_ratio=0.2, test_ratio=0.5)
scaled_data = scale_data(shuffled_data)
num_epochs = 20
batch_size = 12
loss_function = keras.losses.MeanSquaredError()
optimizer = keras.optimizers.Adam()

# Define model 1 - Structure 1 with Relu activation
model1 = keras.Sequential([
    keras.layers.Dense(units=12, activation='relu', input_shape=(1,)),
    keras.layers.Dense(units=8, activation='relu'),
    keras.layers.Dense(units=4, activation='relu'),
    keras.layers.Dense(units=1)
])
model1.compile(loss=loss_function, optimizer=optimizer)
history1 = model1.fit(train_data[:, 0], train_data[:, 1], epochs=num_epochs, batch_size=batch_size,
                      validation_data=(val_data[:, 0], val_data[:, 1]))
y_pred1 = model1.predict(test_data[:, 0])
mse1 = mean_squared_error(test_data[:, 1], y_pred1)
mae1 = mean_absolute_error(test_data[:, 1], y_pred1)
rmse1 = np.sqrt(mse1)
r2_score1 = r2_score(test_data[:, 1], y_pred1)

# Evaluate model 2 with shuffled and scaled data
y_pred2 = model1.predict(scale_data(test_data[:, 0]))
mse2 = mean_squared_error(test_data[:, 1], y_pred2)
mae2 = mean_absolute_error(test_data[:, 1], y_pred2)
rmse2 = np.sqrt(mse2)
r2_score2 = r2_score(test_data[:, 1], y_pred2)
y_pred2 = model1.predict(test_data[:, 0])
plt.scatter(test_data[:, 0], test_data[:, 1], label='Actual')
plt.scatter(test_data[:, 0], y_pred2, label='Predicted')
plt.legend()
plt.show()

#Print metrics for model 2
print('MAE of model 2:', mae2)
print('MSE of model 2:', mse2)
print('RMSE of model 2:', rmse2)
print('R2 score of model 2:', r2_score2)

#--------------------------Case 2---------------------------------
# Setup
num_samples = 30000
shuffled_data = create_data(num_samples, shuffle=True)
train_data, val_data, test_data = train_val_test_split(shuffled_data, train_ratio=0.3, val_ratio=0.2, test_ratio=0.5)
x_train = train_data[:, 0]
y_train = train_data[:, 1]
x_val = val_data[:, 0]
y_val = val_data[:, 1]
x_test = test_data[:, 0]
y_test = test_data[:, 1]
num_epochs = 20
batch_size = 12
loss_fn = tf.keras.losses.MSE

# Define the optimizer
optimizer = tf.keras.optimizers.Adam()
model = tf.keras.Sequential([
    tf.keras.layers.Dense(24, activation='relu', input_shape=(1,)),
    tf.keras.layers.Dense(1)
])

# Compile the model
model.compile(optimizer=optimizer, loss=loss_fn)
history = model.fit(x_train, y_train, validation_data=(x_val, y_val), epochs=num_epochs, batch_size=batch_size)
y_pred = model.predict(x_test).flatten()

# Calculate regression metrics
y_pred = model.predict(scale_data(test_data[:,0]))
mse = mean_squared_error(test_data[:,1], y_pred)
mae = mean_absolute_error(test_data[:,1], y_pred)
rmse = np.sqrt(mse)
r2_score = r2_score(test_data[:,1], y_pred)

print(f'MAE: {mae:.3f}, MSE: {mse:.3f}, RMSE: {rmse:.3f}, R2 score: {r2:.3f}')
plt.scatter(x_test, y_test, s=0.1, label='Actual')
plt.scatter(x_test, y_pred, s=0.1, label='Predicted')
plt.xlabel('x')
plt.ylabel('y')
plt.title('Shuffled and unscaled data, Structure 2, Relu activation function')
plt.legend()
plt.show()

plt.plot(history.history['loss'], label='Training loss')
plt.plot(history.history['val_loss'], label='Validation loss')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.title('Training and validation loss curves')
plt.legend()
plt.show()

#----------------------------Case 3-------------------------------------
# Setup
num_samples = 30000
shuffled_data = create_data(num_samples, shuffle=True)
unshuffled_data = create_data(num_samples, shuffle=False)
train_data, val_data, test_data = train_val_test_split(shuffled_data, train_ratio=0.3, val_ratio=0.2, test_ratio=0.5)
train_data2, val_data2, test_data2 = train_val_test_split(unshuffled_data, train_ratio=0.3, val_ratio=0.2, test_ratio=0.5)
epochs = 20
batch_size = 12
loss_function = 'mse'
optimizer = 'adam'

# Define the model
model = Sequential()
model.add(Dense(12, input_dim=1, activation='tanh'))
model.add(Dense(8, activation='tanh'))
model.add(Dense(4, activation='tanh'))
model.add(Dense(1))
model.compile(loss=loss_function, optimizer=optimizer, metrics=['mae', 'mse'])
model.compile(loss=loss_function, optimizer=optimizer, metrics=['mean_absolute_error'])
model.compile(loss=loss_function, optimizer=optimizer, metrics=['mean_squared_error'])
history = model.fit(train_data[:, 0], train_data[:, 1], epochs=epochs, batch_size=batch_size, validation_data=(val_data[:, 0], val_data[:, 1]))
test_loss, test_mse = model.evaluate(test_data[:, 0], test_data[:, 1])
print("Test Loss:", test_loss)
print("Test MSE:", test_mse)
predictions = model.predict(test_data[:, 0])

# Plot actual vs. predicted
plt.scatter(test_data[:, 0], test_data[:, 1], s=0.1, label='Actual')
plt.scatter(test_data[:, 0], predictions, s=0.1, label='Predicted')
plt.xlabel('x')
plt.ylabel('y')
plt.title('Actual vs. Predicted (Case 3)')
plt.legend()
plt.show()

plt.plot(history.history['loss'], label='Training Loss')
plt.plot(history.history['val_loss'], label='Validation Loss')
plt.xlabel('Epoch')
plt.ylabel('Loss/Metric')
plt.title('Loss and Metrics over Epochs (Case 3)')
plt.legend()
plt.show()

# -----------------------------Case 4---------------------------------------
# Setup
data = create_data(num_samples=1000, shuffle=True)
train_data, val_data, test_data = train_val_test_split(data, train_ratio=0.3, val_ratio=0.2, test_ratio=0.5)
x_train, y_train = train_data[:, 0], train_data[:, 1]
x_val, y_val = val_data[:, 0], val_data[:, 1]
x_test, y_test = test_data[:, 0], test_data[:, 1]
x_train = scale_data(x_train)
y_train = scale_data(y_train)
x_val = scale_data(x_val)
y_val = scale_data(y_val)
x_test = scale_data(x_test)
y_test = scale_data(y_test)

# Define model
model = Sequential([
    Dense(10, activation='relu', input_shape=(1,)),
    Dense(1)
])
model.compile(optimizer='adam', loss='mse')
history = model.fit(x_train, y_train, epochs=20, batch_size=12, validation_data=(x_val, y_val))
y_pred = model.predict(x_test)
mse = mean_squared_error(y_test, y_pred)
mae = mean_absolute_error(y_test, y_pred)

# Print metrics
print("MSE:", mse)
print("MAE:", mae)

# Plot training and validation loss
plt.plot(history.history['loss'], label='Training Loss')
plt.plot(history.history['val_loss'], label='Validation Loss')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.title('Training and Validation Loss')
plt.legend()
plt.show()

plt.scatter(x_test, y_test, label='Actual Values')
plt.scatter(x_test, y_pred, label='Predicted Values')
plt.xlabel('x')
plt.ylabel('y')
plt.title('Actual vs Predicted Values')
plt.legend()
plt.show()

# --------------------------Case 5----------------------------------------
# Setup
tf.random.set_seed(42)
np.random.seed(42)
model = Sequential([
    Dense(20, input_shape=(1,), activation='tanh'),
    Dense(20, activation='tanh'),
    Dense(1)
])
num_samples = 1000
data = create_data(num_samples, shuffle=True)

# Compile model
model.compile(loss='mse', optimizer='adam')
train_data, val_data, test_data = train_val_test_split(data, train_ratio=0.3, val_ratio=0.2, test_ratio=0.5)
train_data_scaled = scale_data(train_data)
val_data_scaled = scale_data(val_data)
test_data_scaled = scale_data(test_data)

# Train model
history = model.fit(train_data_scaled[:, 0], train_data_scaled[:, 1],
                    validation_data=(val_data_scaled[:, 0], val_data_scaled[:, 1]),
                    epochs=20, batch_size=12)

y_pred_scaled = model.predict(test_data_scaled[:, 0])
y_test_scaled = test_data_scaled[:, 1]
X_test_unscaled = test_data[:, 0].reshape(-1, 1)
y_test_unscaled = test_data[:, 1].reshape(-1, 1)
y_pred_unscaled = y_pred_scaled * (np.max(y_test_unscaled) - np.min(y_test_unscaled)) + np.min(y_test_unscaled)

mae = mean_absolute_error(y_test_unscaled, y_pred_unscaled)
mse = mean_squared_error(y_test_unscaled, y_pred_unscaled)
rmse = np.sqrt(mse)

# Print metrics
print(f'MAE: {mae:.2f}')
print(f'MSE: {mse:.2f}')
print(f'RMSE: {rmse:.2f}')

# Create plots
fig, ax = plt.subplots(2, 1, figsize=(8, 10))
ax[0].scatter(X_test_unscaled, y_test_unscaled, label='Actual')
ax[0].scatter(X_test_unscaled, y_pred_unscaled, label='Predicted')
ax[0].set_xlabel('X Test')
ax[0].set_ylabel('Y')
ax[0].set_title('Actual vs. Predicted')
ax[0].legend()

ax[1].scatter(X_test_unscaled, y_test_unscaled - y_pred_unscaled, label='Residuals')
ax[1].set_xlabel('X Test')
ax[1].set_ylabel('Residuals')
ax[1].set_title('Residuals')
ax[1].legend()

plt.tight_layout()
plt.show()
# Out:
# Epoch 1/20
# 750/750 [==============================] - 3s 3ms/step - loss: 21.8244 - val_loss: 0.2495
# Epoch 2/20
# 750/750 [==============================] - 2s 3ms/step - loss: 0.1600 - val_loss: 0.1092
# Epoch 3/20
# 750/750 [==============================] - 3s 5ms/step - loss: 0.0602 - val_loss: 0.0269
# Epoch 4/20
# 750/750 [==============================] - 2s 3ms/step - loss: 0.0158 - val_loss: 0.0093
# Epoch 5/20
# 750/750 [==============================] - 2s 3ms/step - loss: 0.0056 - val_loss: 0.0037
# Epoch 6/20
# 750/750 [==============================] - 2s 3ms/step - loss: 0.0031 - val_loss: 0.0026
# Epoch 7/20
# 750/750 [==============================] - 2s 3ms/step - loss: 0.0026 - val_loss: 0.0024
# Epoch 8/20
# 750/750 [==============================] - 3s 4ms/step - loss: 0.0025 - val_loss: 0.0025
# Epoch 9/20
# 750/750 [==============================] - 2s 3ms/step - loss: 0.0025 - val_loss: 0.0026
# Epoch 10/20
# 750/750 [==============================] - 2s 3ms/step - loss: 0.0025 - val_loss: 0.0023
# Epoch 11/20
# 750/750 [==============================] - 2s 3ms/step - loss: 0.0024 - val_loss: 0.0021
# Epoch 12/20
# 750/750 [==============================] - 2s 3ms/step - loss: 0.0025 - val_loss: 0.0023
# Epoch 13/20
# 750/750 [==============================] - 2s 3ms/step - loss: 0.0024 - val_loss: 0.0023
# Epoch 14/20
# 750/750 [==============================] - 3s 4ms/step - loss: 0.0023 - val_loss: 0.0024
# Epoch 15/20
# 750/750 [==============================] - 2s 3ms/step - loss: 0.0023 - val_loss: 0.0026
# Epoch 16/20
# 750/750 [==============================] - 2s 3ms/step - loss: 0.0023 - val_loss: 0.0020
# Epoch 17/20
# 750/750 [==============================] - 2s 3ms/step - loss: 0.0021 - val_loss: 0.0022
# Epoch 18/20
# 750/750 [==============================] - 2s 3ms/step - loss: 0.0022 - val_loss: 0.0020
# Epoch 19/20
# 750/750 [==============================] - 2s 3ms/step - loss: 0.0021 - val_loss: 0.0018
# Epoch 20/20
# 750/750 [==============================] - 3s 4ms/step - loss: 0.0022 - val_loss: 0.0022
# 469/469 [==============================] - 1s 1ms/step
# 469/469 [==============================] - 1s 1ms/step
# 469/469 [==============================] - 1s 1ms/step
# MAE of model 2: 0.5367719138951007
# MSE of model 2: 0.3976601360764225
# RMSE of model 2: 0.6306029940274804
# R2 score of model 2: 0.31892569695975037
# Epoch 1/20
# 750/750 [==============================] - 3s 3ms/step - loss: 40.4957 - val_loss: 0.2046
# Epoch 2/20
# 750/750 [==============================] - 3s 3ms/step - loss: 0.0997 - val_loss: 0.0811
# Epoch 3/20
# 750/750 [==============================] - 2s 3ms/step - loss: 0.0694 - val_loss: 0.0617
# Epoch 4/20
# 750/750 [==============================] - 2s 2ms/step - loss: 0.0560 - val_loss: 0.0525
# Epoch 5/20
# 750/750 [==============================] - 2s 3ms/step - loss: 0.0512 - val_loss: 0.0504
# Epoch 6/20
# 750/750 [==============================] - 2s 3ms/step - loss: 0.0503 - val_loss: 0.0499
# Epoch 7/20
# 750/750 [==============================] - 2s 3ms/step - loss: 0.0497 - val_loss: 0.0491
# Epoch 8/20
# 750/750 [==============================] - 2s 3ms/step - loss: 0.0494 - val_loss: 0.0488
# Epoch 9/20
# 750/750 [==============================] - 2s 3ms/step - loss: 0.0489 - val_loss: 0.0503
# Epoch 10/20
# 750/750 [==============================] - 2s 3ms/step - loss: 0.0479 - val_loss: 0.0473
# Epoch 11/20
# 750/750 [==============================] - 2s 2ms/step - loss: 0.0473 - val_loss: 0.0471
# Epoch 12/20
# 750/750 [==============================] - 2s 2ms/step - loss: 0.0471 - val_loss: 0.0484
# Epoch 13/20
# 750/750 [==============================] - 2s 2ms/step - loss: 0.0469 - val_loss: 0.0463
# Epoch 14/20
# 750/750 [==============================] - 3s 4ms/step - loss: 0.0462 - val_loss: 0.0476
# Epoch 15/20
# 750/750 [==============================] - 3s 3ms/step - loss: 0.0463 - val_loss: 0.0476
# Epoch 16/20
# 750/750 [==============================] - 2s 3ms/step - loss: 0.0457 - val_loss: 0.0456
# Epoch 17/20
# 750/750 [==============================] - 2s 2ms/step - loss: 0.0457 - val_loss: 0.0448
# Epoch 18/20
# 750/750 [==============================] - 2s 2ms/step - loss: 0.0455 - val_loss: 0.0449
# Epoch 19/20
# 750/750 [==============================] - 2s 3ms/step - loss: 0.0452 - val_loss: 0.0444
# Epoch 20/20
# 750/750 [==============================] - 3s 4ms/step - loss: 0.0451 - val_loss: 0.0441
# 469/469 [==============================] - 1s 2ms/step
# 469/469 [==============================] - 1s 1ms/step
# MAE: 0.577, MSE: 0.422, RMSE: 0.649, R2 score: 0.875
# Epoch 1/20
# 750/750 [==============================] - 3s 3ms/step - loss: 39.4646 - mean_squared_error: 39.4646 - val_loss: 16.5946 - val_mean_squared_error: 16.5946
# Epoch 2/20
# 750/750 [==============================] - 2s 3ms/step - loss: 8.5498 - mean_squared_error: 8.5498 - val_loss: 3.4522 - val_mean_squared_error: 3.4522
# Epoch 3/20
# 750/750 [==============================] - 3s 4ms/step - loss: 1.6901 - mean_squared_error: 1.6901 - val_loss: 0.8087 - val_mean_squared_error: 0.8087
# Epoch 4/20
# 750/750 [==============================] - 3s 4ms/step - loss: 0.6293 - mean_squared_error: 0.6293 - val_loss: 0.5711 - val_mean_squared_error: 0.5711
# Epoch 5/20
# 750/750 [==============================] - 3s 4ms/step - loss: 0.4939 - mean_squared_error: 0.4939 - val_loss: 0.3081 - val_mean_squared_error: 0.3081
# Epoch 6/20
# 750/750 [==============================] - 2s 3ms/step - loss: 0.2569 - mean_squared_error: 0.2569 - val_loss: 0.2219 - val_mean_squared_error: 0.2219
# Epoch 7/20
# 750/750 [==============================] - 2s 3ms/step - loss: 0.1913 - mean_squared_error: 0.1913 - val_loss: 0.1707 - val_mean_squared_error: 0.1707
# Epoch 8/20
# 750/750 [==============================] - 3s 3ms/step - loss: 0.1467 - mean_squared_error: 0.1467 - val_loss: 0.1207 - val_mean_squared_error: 0.1207
# Epoch 9/20
# 750/750 [==============================] - 3s 3ms/step - loss: 0.0659 - mean_squared_error: 0.0659 - val_loss: 0.0306 - val_mean_squared_error: 0.0306
# Epoch 10/20
# 750/750 [==============================] - 2s 3ms/step - loss: 0.0183 - mean_squared_error: 0.0183 - val_loss: 0.0098 - val_mean_squared_error: 0.0098
# Epoch 11/20
# 750/750 [==============================] - 2s 3ms/step - loss: 0.0063 - mean_squared_error: 0.0063 - val_loss: 0.0037 - val_mean_squared_error: 0.0037
# Epoch 12/20
# 750/750 [==============================] - 2s 3ms/step - loss: 0.0027 - mean_squared_error: 0.0027 - val_loss: 0.0020 - val_mean_squared_error: 0.0020
# Epoch 13/20
# 750/750 [==============================] - 2s 3ms/step - loss: 0.0016 - mean_squared_error: 0.0016 - val_loss: 0.0012 - val_mean_squared_error: 0.0012
# Epoch 14/20
# 750/750 [==============================] - 3s 5ms/step - loss: 0.0012 - mean_squared_error: 0.0012 - val_loss: 0.0011 - val_mean_squared_error: 0.0011
# Epoch 15/20
# 750/750 [==============================] - 2s 3ms/step - loss: 8.8507e-04 - mean_squared_error: 8.8507e-04 - val_loss: 8.1496e-04 - val_mean_squared_error: 8.1496e-04
# Epoch 16/20
# 750/750 [==============================] - 2s 3ms/step - loss: 8.0536e-04 - mean_squared_error: 8.0536e-04 - val_loss: 5.1705e-04 - val_mean_squared_error: 5.1705e-04
# Epoch 17/20
# 750/750 [==============================] - 2s 3ms/step - loss: 6.4248e-04 - mean_squared_error: 6.4248e-04 - val_loss: 5.5290e-04 - val_mean_squared_error: 5.5290e-04
# Epoch 18/20
# 750/750 [==============================] - 2s 3ms/step - loss: 5.2126e-04 - mean_squared_error: 5.2126e-04 - val_loss: 3.9098e-04 - val_mean_squared_error: 3.9098e-04
# Epoch 19/20
# 750/750 [==============================] - 3s 4ms/step - loss: 4.7059e-04 - mean_squared_error: 4.7059e-04 - val_loss: 3.7826e-04 - val_mean_squared_error: 3.7826e-04
# Epoch 20/20
# 750/750 [==============================] - 2s 3ms/step - loss: 4.1828e-04 - mean_squared_error: 4.1828e-04 - val_loss: 3.2613e-04 - val_mean_squared_error: 3.2613e-04
# 469/469 [==============================] - 1s 2ms/step - loss: 3.3100e-04 - mean_squared_error: 3.3100e-04
# Test Loss: 0.000330997136188671
# Test MSE: 0.000330997136188671
# 469/469 [==============================] - 1s 1ms/step
# Epoch 1/20
# 25/25 [==============================] - 1s 10ms/step - loss: 0.1143 - val_loss: 0.0852
# Epoch 2/20
# 25/25 [==============================] - 0s 4ms/step - loss: 0.0589 - val_loss: 0.0416
# Epoch 3/20
# 25/25 [==============================] - 0s 6ms/step - loss: 0.0277 - val_loss: 0.0194
# Epoch 4/20
# 25/25 [==============================] - 0s 6ms/step - loss: 0.0137 - val_loss: 0.0106
# Epoch 5/20
# 25/25 [==============================] - 0s 5ms/step - loss: 0.0089 - val_loss: 0.0079
# Epoch 6/20
# 25/25 [==============================] - 0s 5ms/step - loss: 0.0077 - val_loss: 0.0072
# Epoch 7/20
# 25/25 [==============================] - 0s 6ms/step - loss: 0.0074 - val_loss: 0.0070
# Epoch 8/20
# 25/25 [==============================] - 0s 4ms/step - loss: 0.0073 - val_loss: 0.0068
# Epoch 9/20
# 25/25 [==============================] - 0s 6ms/step - loss: 0.0071 - val_loss: 0.0067
# Epoch 10/20
# 25/25 [==============================] - 0s 5ms/step - loss: 0.0070 - val_loss: 0.0067
# Epoch 11/20
# 25/25 [==============================] - 0s 6ms/step - loss: 0.0069 - val_loss: 0.0066
# Epoch 12/20
# 25/25 [==============================] - 0s 6ms/step - loss: 0.0068 - val_loss: 0.0065
# Epoch 13/20
# 25/25 [==============================] - 0s 5ms/step - loss: 0.0067 - val_loss: 0.0064
# Epoch 14/20
# 25/25 [==============================] - 0s 6ms/step - loss: 0.0066 - val_loss: 0.0063
# Epoch 15/20
# 25/25 [==============================] - 0s 4ms/step - loss: 0.0065 - val_loss: 0.0063
# Epoch 16/20
# 25/25 [==============================] - 0s 5ms/step - loss: 0.0065 - val_loss: 0.0062
# Epoch 17/20
# 25/25 [==============================] - 0s 5ms/step - loss: 0.0064 - val_loss: 0.0062
# Epoch 18/20
# 25/25 [==============================] - 0s 6ms/step - loss: 0.0064 - val_loss: 0.0061
# Epoch 19/20
# 25/25 [==============================] - 0s 6ms/step - loss: 0.0063 - val_loss: 0.0061
# Epoch 20/20
# 25/25 [==============================] - 0s 4ms/step - loss: 0.0063 - val_loss: 0.0061
# 16/16 [==============================] - 0s 2ms/step
# MSE: 0.006363008449927348
# MAE: 0.06404294276114765
# Epoch 1/20
# 25/25 [==============================] - 2s 16ms/step - loss: 0.0092 - val_loss: 0.0063
# Epoch 2/20
# 25/25 [==============================] - 0s 4ms/step - loss: 0.0078 - val_loss: 0.0058
# Epoch 3/20
# 25/25 [==============================] - 0s 4ms/step - loss: 0.0076 - val_loss: 0.0057
# Epoch 4/20
# 25/25 [==============================] - 0s 7ms/step - loss: 0.0074 - val_loss: 0.0062
# Epoch 5/20
# 25/25 [==============================] - 0s 6ms/step - loss: 0.0082 - val_loss: 0.0058
# Epoch 6/20
# 25/25 [==============================] - 0s 6ms/step - loss: 0.0077 - val_loss: 0.0061
# Epoch 7/20
# 25/25 [==============================] - 0s 4ms/step - loss: 0.0079 - val_loss: 0.0057
# Epoch 8/20
# 25/25 [==============================] - 0s 6ms/step - loss: 0.0077 - val_loss: 0.0059
# Epoch 9/20
# 25/25 [==============================] - 0s 4ms/step - loss: 0.0073 - val_loss: 0.0057
# Epoch 10/20
# 25/25 [==============================] - 0s 5ms/step - loss: 0.0073 - val_loss: 0.0063
# Epoch 11/20
# 25/25 [==============================] - 0s 4ms/step - loss: 0.0074 - val_loss: 0.0058
# Epoch 12/20
# 25/25 [==============================] - 0s 6ms/step - loss: 0.0075 - val_loss: 0.0059
# Epoch 13/20
# 25/25 [==============================] - 0s 4ms/step - loss: 0.0073 - val_loss: 0.0057
# Epoch 14/20
# 25/25 [==============================] - 0s 6ms/step - loss: 0.0074 - val_loss: 0.0057
# Epoch 15/20
# 25/25 [==============================] - 0s 6ms/step - loss: 0.0075 - val_loss: 0.0057
# Epoch 16/20
# 25/25 [==============================] - 0s 4ms/step - loss: 0.0075 - val_loss: 0.0057
# Epoch 17/20
# 25/25 [==============================] - 0s 7ms/step - loss: 0.0074 - val_loss: 0.0056
# Epoch 18/20
# 25/25 [==============================] - 0s 5ms/step - loss: 0.0072 - val_loss: 0.0057
# Epoch 19/20
# 25/25 [==============================] - 0s 6ms/step - loss: 0.0075 - val_loss: 0.0058
# Epoch 20/20
# 25/25 [==============================] - 0s 4ms/step - loss: 0.0075 - val_loss: 0.0065
# 16/16 [==============================] - 1s 2ms/step
# MAE: 0.30
# MSE: 0.13
# RMSE: 0.36

# %% [markdown]
# The Code above is Question 5

# %%
import numpy as np
from keras.models import Sequential
from keras.layers import Dense

# Create the dataset
X = np.array([[0, 0], [0, 1], [1, 0], [1, 1]])
y = np.array([[0], [1], [1], [0]])

# Define the neural network model
model = Sequential()
model.add(Dense(8, input_dim=2, activation='relu'))
model.add(Dense(4, activation='relu'))
model.add(Dense(1, activation='sigmoid'))

# Compile the model
model.compile(loss='binary_crossentropy', optimizer='adam', metrics=['accuracy'])

# Train the model
model.fit(X, y, epochs=300, batch_size=4)

# Test the model
predictions = model.predict(X)
rounded_predictions = np.round(predictions)
print(rounded_predictions)
# Out:
# Epoch 1/300
# 1/1 [==============================] - 1s 823ms/step - loss: 0.7385 - accuracy: 0.7500
# Epoch 2/300
# 1/1 [==============================] - 0s 17ms/step - loss: 0.7378 - accuracy: 0.5000
# Epoch 3/300
# 1/1 [==============================] - 0s 11ms/step - loss: 0.7366 - accuracy: 0.7500
# Epoch 4/300
# 1/1 [==============================] - 0s 11ms/step - loss: 0.7355 - accuracy: 0.7500
# Epoch 5/300
# 1/1 [==============================] - 0s 14ms/step - loss: 0.7344 - accuracy: 0.7500
# Epoch 6/300
# 1/1 [==============================] - 0s 15ms/step - loss: 0.7334 - accuracy: 0.7500
# Epoch 7/300
# 1/1 [==============================] - 0s 18ms/step - loss: 0.7325 - accuracy: 0.7500
# Epoch 8/300
# 1/1 [==============================] - 0s 12ms/step - loss: 0.7315 - accuracy: 0.7500
# Epoch 9/300
# 1/1 [==============================] - 0s 13ms/step - loss: 0.7306 - accuracy: 0.7500
# Epoch 10/300
# 1/1 [==============================] - 0s 11ms/step - loss: 0.7296 - accuracy: 0.7500
# Epoch 11/300
# 1/1 [==============================] - 0s 14ms/step - loss: 0.7287 - accuracy: 0.7500
# Epoch 12/300
# 1/1 [==============================] - 0s 13ms/step - loss: 0.7278 - accuracy: 0.7500
# Epoch 13/300
# 1/1 [==============================] - 0s 11ms/step - loss: 0.7269 - accuracy: 0.7500
# Epoch 14/300
# 1/1 [==============================] - 0s 15ms/step - loss: 0.7260 - accuracy: 0.7500
# Epoch 15/300
# 1/1 [==============================] - 0s 14ms/step - loss: 0.7252 - accuracy: 0.7500
# Epoch 16/300
# 1/1 [==============================] - 0s 11ms/step - loss: 0.7244 - accuracy: 0.7500
# Epoch 17/300
# 1/1 [==============================] - 0s 11ms/step - loss: 0.7235 - accuracy: 0.7500
# Epoch 18/300
# 1/1 [==============================] - 0s 11ms/step - loss: 0.7227 - accuracy: 0.7500
# Epoch 19/300
# 1/1 [==============================] - 0s 12ms/step - loss: 0.7219 - accuracy: 0.7500
# Epoch 20/300
# 1/1 [==============================] - 0s 12ms/step - loss: 0.7211 - accuracy: 0.7500
# Epoch 21/300
# 1/1 [==============================] - 0s 12ms/step - loss: 0.7204 - accuracy: 0.7500
# Epoch 22/300
# 1/1 [==============================] - 0s 13ms/step - loss: 0.7196 - accuracy: 0.7500
# Epoch 23/300
# 1/1 [==============================] - 0s 11ms/step - loss: 0.7189 - accuracy: 0.7500
# Epoch 24/300
# 1/1 [==============================] - 0s 11ms/step - loss: 0.7182 - accuracy: 0.7500
# Epoch 25/300
# 1/1 [==============================] - 0s 11ms/step - loss: 0.7174 - accuracy: 0.7500
# Epoch 26/300
# 1/1 [==============================] - 0s 10ms/step - loss: 0.7167 - accuracy: 0.7500
# Epoch 27/300
# 1/1 [==============================] - 0s 11ms/step - loss: 0.7161 - accuracy: 0.7500
# Epoch 28/300
# 1/1 [==============================] - 0s 12ms/step - loss: 0.7154 - accuracy: 0.7500
# Epoch 29/300
# 1/1 [==============================] - 0s 12ms/step - loss: 0.7147 - accuracy: 0.7500
# Epoch 30/300
# 1/1 [==============================] - 0s 12ms/step - loss: 0.7141 - accuracy: 0.7500
# Epoch 31/300
# 1/1 [==============================] - 0s 11ms/step - loss: 0.7135 - accuracy: 0.7500
# Epoch 32/300
# 1/1 [==============================] - 0s 11ms/step - loss: 0.7129 - accuracy: 0.7500
# Epoch 33/300
# 1/1 [==============================] - 0s 11ms/step - loss: 0.7123 - accuracy: 0.7500
# Epoch 34/300
# 1/1 [==============================] - 0s 11ms/step - loss: 0.7117 - accuracy: 0.7500
# Epoch 35/300
# 1/1 [==============================] - 0s 12ms/step - loss: 0.7112 - accuracy: 0.7500
# Epoch 36/300
# 1/1 [==============================] - 0s 12ms/step - loss: 0.7106 - accuracy: 0.7500
# Epoch 37/300
# 1/1 [==============================] - 0s 13ms/step - loss: 0.7100 - accuracy: 0.7500
# Epoch 38/300
# 1/1 [==============================] - 0s 12ms/step - loss: 0.7095 - accuracy: 0.7500
# Epoch 39/300
# 1/1 [==============================] - 0s 12ms/step - loss: 0.7090 - accuracy: 0.7500
# Epoch 40/300
# 1/1 [==============================] - 0s 13ms/step - loss: 0.7085 - accuracy: 0.7500
# Epoch 41/300
# 1/1 [==============================] - 0s 13ms/step - loss: 0.7080 - accuracy: 0.7500
# Epoch 42/300
# 1/1 [==============================] - 0s 14ms/step - loss: 0.7075 - accuracy: 0.7500
# Epoch 43/300
# 1/1 [==============================] - 0s 12ms/step - loss: 0.7071 - accuracy: 0.7500
# Epoch 44/300
# 1/1 [==============================] - 0s 14ms/step - loss: 0.7066 - accuracy: 0.7500
# Epoch 45/300
# 1/1 [==============================] - 0s 13ms/step - loss: 0.7062 - accuracy: 0.7500
# Epoch 46/300
# 1/1 [==============================] - 0s 11ms/step - loss: 0.7057 - accuracy: 0.7500
# Epoch 47/300
# 1/1 [==============================] - 0s 12ms/step - loss: 0.7053 - accuracy: 0.7500
# Epoch 48/300
# 1/1 [==============================] - 0s 11ms/step - loss: 0.7049 - accuracy: 0.7500
# Epoch 49/300
# 1/1 [==============================] - 0s 13ms/step - loss: 0.7045 - accuracy: 0.7500
# Epoch 50/300
# 1/1 [==============================] - 0s 12ms/step - loss: 0.7041 - accuracy: 0.7500
# Epoch 51/300
# 1/1 [==============================] - 0s 10ms/step - loss: 0.7037 - accuracy: 0.7500
# Epoch 52/300
# 1/1 [==============================] - 0s 11ms/step - loss: 0.7033 - accuracy: 0.7500
# Epoch 53/300
# 1/1 [==============================] - 0s 11ms/step - loss: 0.7029 - accuracy: 0.7500
# Epoch 54/300
# 1/1 [==============================] - 0s 11ms/step - loss: 0.7026 - accuracy: 0.7500
# Epoch 55/300
# 1/1 [==============================] - 0s 12ms/step - loss: 0.7023 - accuracy: 0.7500
# Epoch 56/300
# 1/1 [==============================] - 0s 11ms/step - loss: 0.7019 - accuracy: 0.7500
# Epoch 57/300
# 1/1 [==============================] - 0s 12ms/step - loss: 0.7016 - accuracy: 0.7500
# Epoch 58/300
# 1/1 [==============================] - 0s 12ms/step - loss: 0.7012 - accuracy: 0.7500
# Epoch 59/300
# 1/1 [==============================] - 0s 12ms/step - loss: 0.7009 - accuracy: 0.7500
# Epoch 60/300
# 1/1 [==============================] - 0s 11ms/step - loss: 0.7006 - accuracy: 0.7500
# Epoch 61/300
# 1/1 [==============================] - 0s 12ms/step - loss: 0.7003 - accuracy: 0.7500
# Epoch 62/300
# 1/1 [==============================] - 0s 11ms/step - loss: 0.7000 - accuracy: 0.7500
# Epoch 63/300
# 1/1 [==============================] - 0s 11ms/step - loss: 0.6998 - accuracy: 0.7500
# Epoch 64/300
# 1/1 [==============================] - 0s 11ms/step - loss: 0.6995 - accuracy: 0.7500
# Epoch 65/300
# 1/1 [==============================] - 0s 12ms/step - loss: 0.6992 - accuracy: 0.7500
# Epoch 66/300
# 1/1 [==============================] - 0s 12ms/step - loss: 0.6990 - accuracy: 0.7500
# Epoch 67/300
# 1/1 [==============================] - 0s 12ms/step - loss: 0.6987 - accuracy: 0.7500
# Epoch 68/300
# 1/1 [==============================] - 0s 11ms/step - loss: 0.6984 - accuracy: 0.7500
# Epoch 69/300
# 1/1 [==============================] - 0s 12ms/step - loss: 0.6982 - accuracy: 0.7500
# Epoch 70/300
# 1/1 [==============================] - 0s 11ms/step - loss: 0.6980 - accuracy: 0.7500
# Epoch 71/300
# 1/1 [==============================] - 0s 13ms/step - loss: 0.6977 - accuracy: 0.7500
# Epoch 72/300
# 1/1 [==============================] - 0s 12ms/step - loss: 0.6974 - accuracy: 0.7500
# Epoch 73/300
# 1/1 [==============================] - 0s 11ms/step - loss: 0.6972 - accuracy: 0.7500
# Epoch 74/300
# 1/1 [==============================] - 0s 12ms/step - loss: 0.6970 - accuracy: 0.7500
# Epoch 75/300
# 1/1 [==============================] - 0s 12ms/step - loss: 0.6968 - accuracy: 0.7500
# Epoch 76/300
# 1/1 [==============================] - 0s 15ms/step - loss: 0.6966 - accuracy: 0.7500
# Epoch 77/300
# 1/1 [==============================] - 0s 12ms/step - loss: 0.6964 - accuracy: 0.7500
# Epoch 78/300
# 1/1 [==============================] - 0s 15ms/step - loss: 0.6962 - accuracy: 0.7500
# Epoch 79/300
# 1/1 [==============================] - 0s 12ms/step - loss: 0.6960 - accuracy: 0.7500
# Epoch 80/300
# 1/1 [==============================] - 0s 12ms/step - loss: 0.6958 - accuracy: 0.7500
# Epoch 81/300
# 1/1 [==============================] - 0s 11ms/step - loss: 0.6956 - accuracy: 0.7500
# Epoch 82/300
# 1/1 [==============================] - 0s 14ms/step - loss: 0.6954 - accuracy: 0.7500
# Epoch 83/300
# 1/1 [==============================] - 0s 12ms/step - loss: 0.6952 - accuracy: 0.7500
# Epoch 84/300
# 1/1 [==============================] - 0s 11ms/step - loss: 0.6951 - accuracy: 0.7500
# Epoch 85/300
# 1/1 [==============================] - 0s 11ms/step - loss: 0.6949 - accuracy: 0.7500
# Epoch 86/300
# 1/1 [==============================] - 0s 12ms/step - loss: 0.6946 - accuracy: 0.7500
# Epoch 87/300
# 1/1 [==============================] - 0s 12ms/step - loss: 0.6940 - accuracy: 0.7500
# Epoch 88/300
# 1/1 [==============================] - 0s 13ms/step - loss: 0.6934 - accuracy: 0.7500
# Epoch 89/300
# 1/1 [==============================] - 0s 19ms/step - loss: 0.6927 - accuracy: 0.7500
# Epoch 90/300
# 1/1 [==============================] - 0s 11ms/step - loss: 0.6919 - accuracy: 0.7500
# Epoch 91/300
# 1/1 [==============================] - 0s 12ms/step - loss: 0.6910 - accuracy: 0.7500
# Epoch 92/300
# 1/1 [==============================] - 0s 11ms/step - loss: 0.6902 - accuracy: 0.7500
# Epoch 93/300
# 1/1 [==============================] - 0s 11ms/step - loss: 0.6893 - accuracy: 0.7500
# Epoch 94/300
# 1/1 [==============================] - 0s 12ms/step - loss: 0.6884 - accuracy: 0.7500
# Epoch 95/300
# 1/1 [==============================] - 0s 12ms/step - loss: 0.6874 - accuracy: 0.7500
# Epoch 96/300
# 1/1 [==============================] - 0s 12ms/step - loss: 0.6865 - accuracy: 0.7500
# Epoch 97/300
# 1/1 [==============================] - 0s 12ms/step - loss: 0.6855 - accuracy: 0.7500
# Epoch 98/300
# 1/1 [==============================] - 0s 12ms/step - loss: 0.6845 - accuracy: 0.7500
# Epoch 99/300
# 1/1 [==============================] - 0s 12ms/step - loss: 0.6835 - accuracy: 0.7500
# Epoch 100/300
# 1/1 [==============================] - 0s 11ms/step - loss: 0.6825 - accuracy: 0.7500
# Epoch 101/300
# 1/1 [==============================] - 0s 10ms/step - loss: 0.6815 - accuracy: 0.7500
# Epoch 102/300
# 1/1 [==============================] - 0s 13ms/step - loss: 0.6804 - accuracy: 0.7500
# Epoch 103/300
# 1/1 [==============================] - 0s 12ms/step - loss: 0.6794 - accuracy: 0.7500
# Epoch 104/300
# 1/1 [==============================] - 0s 14ms/step - loss: 0.6784 - accuracy: 0.7500
# Epoch 105/300
# 1/1 [==============================] - 0s 18ms/step - loss: 0.6773 - accuracy: 0.7500
# Epoch 106/300
# 1/1 [==============================] - 0s 11ms/step - loss: 0.6763 - accuracy: 0.7500
# Epoch 107/300
# 1/1 [==============================] - 0s 11ms/step - loss: 0.6753 - accuracy: 0.7500
# Epoch 108/300
# 1/1 [==============================] - 0s 11ms/step - loss: 0.6742 - accuracy: 0.7500
# Epoch 109/300
# 1/1 [==============================] - 0s 11ms/step - loss: 0.6732 - accuracy: 0.7500
# Epoch 110/300
# 1/1 [==============================] - 0s 10ms/step - loss: 0.6722 - accuracy: 0.7500
# Epoch 111/300
# 1/1 [==============================] - 0s 12ms/step - loss: 0.6712 - accuracy: 0.7500
# Epoch 112/300
# 1/1 [==============================] - 0s 11ms/step - loss: 0.6701 - accuracy: 0.7500
# Epoch 113/300
# 1/1 [==============================] - 0s 11ms/step - loss: 0.6691 - accuracy: 1.0000
# Epoch 114/300
# 1/1 [==============================] - 0s 11ms/step - loss: 0.6681 - accuracy: 1.0000
# Epoch 115/300
# 1/1 [==============================] - 0s 11ms/step - loss: 0.6678 - accuracy: 1.0000
# Epoch 116/300
# 1/1 [==============================] - 0s 11ms/step - loss: 0.6676 - accuracy: 1.0000
# Epoch 117/300
# 1/1 [==============================] - 0s 11ms/step - loss: 0.6673 - accuracy: 1.0000
# Epoch 118/300
# 1/1 [==============================] - 0s 10ms/step - loss: 0.6669 - accuracy: 1.0000
# Epoch 119/300
# 1/1 [==============================] - 0s 10ms/step - loss: 0.6664 - accuracy: 1.0000
# Epoch 120/300
# 1/1 [==============================] - 0s 12ms/step - loss: 0.6658 - accuracy: 1.0000
# Epoch 121/300
# 1/1 [==============================] - 0s 11ms/step - loss: 0.6651 - accuracy: 1.0000
# Epoch 122/300
# 1/1 [==============================] - 0s 11ms/step - loss: 0.6644 - accuracy: 1.0000
# Epoch 123/300
# 1/1 [==============================] - 0s 11ms/step - loss: 0.6636 - accuracy: 1.0000
# Epoch 124/300
# 1/1 [==============================] - 0s 12ms/step - loss: 0.6628 - accuracy: 1.0000
# Epoch 125/300
# 1/1 [==============================] - 0s 10ms/step - loss: 0.6620 - accuracy: 0.7500
# Epoch 126/300
# 1/1 [==============================] - 0s 10ms/step - loss: 0.6615 - accuracy: 0.7500
# Epoch 127/300
# 1/1 [==============================] - 0s 9ms/step - loss: 0.6611 - accuracy: 0.7500
# Epoch 128/300
# 1/1 [==============================] - 0s 10ms/step - loss: 0.6609 - accuracy: 0.7500
# Epoch 129/300
# 1/1 [==============================] - 0s 10ms/step - loss: 0.6606 - accuracy: 0.7500
# Epoch 130/300
# 1/1 [==============================] - 0s 9ms/step - loss: 0.6601 - accuracy: 0.7500
# Epoch 131/300
# 1/1 [==============================] - 0s 9ms/step - loss: 0.6595 - accuracy: 0.7500
# Epoch 132/300
# 1/1 [==============================] - 0s 13ms/step - loss: 0.6588 - accuracy: 0.7500
# Epoch 133/300
# 1/1 [==============================] - 0s 12ms/step - loss: 0.6583 - accuracy: 0.7500
# Epoch 134/300
# 1/1 [==============================] - 0s 11ms/step - loss: 0.6579 - accuracy: 0.7500
# Epoch 135/300
# 1/1 [==============================] - 0s 11ms/step - loss: 0.6575 - accuracy: 0.7500
# Epoch 136/300
# 1/1 [==============================] - 0s 10ms/step - loss: 0.6571 - accuracy: 0.7500
# Epoch 137/300
# 1/1 [==============================] - 0s 10ms/step - loss: 0.6566 - accuracy: 0.7500
# Epoch 138/300
# 1/1 [==============================] - 0s 9ms/step - loss: 0.6560 - accuracy: 0.7500
# Epoch 139/300
# 1/1 [==============================] - 0s 10ms/step - loss: 0.6555 - accuracy: 0.7500
# Epoch 140/300
# 1/1 [==============================] - 0s 10ms/step - loss: 0.6550 - accuracy: 0.7500
# Epoch 141/300
# 1/1 [==============================] - 0s 9ms/step - loss: 0.6543 - accuracy: 0.7500
# Epoch 142/300
# 1/1 [==============================] - 0s 10ms/step - loss: 0.6538 - accuracy: 0.7500
# Epoch 143/300
# 1/1 [==============================] - 0s 10ms/step - loss: 0.6532 - accuracy: 1.0000
# Epoch 144/300
# 1/1 [==============================] - 0s 11ms/step - loss: 0.6530 - accuracy: 1.0000
# Epoch 145/300
# 1/1 [==============================] - 0s 10ms/step - loss: 0.6527 - accuracy: 1.0000
# Epoch 146/300
# 1/1 [==============================] - 0s 10ms/step - loss: 0.6523 - accuracy: 1.0000
# Epoch 147/300
# 1/1 [==============================] - 0s 9ms/step - loss: 0.6517 - accuracy: 1.0000
# Epoch 148/300
# 1/1 [==============================] - 0s 10ms/step - loss: 0.6512 - accuracy: 1.0000
# Epoch 149/300
# 1/1 [==============================] - 0s 10ms/step - loss: 0.6506 - accuracy: 1.0000
# Epoch 150/300
# 1/1 [==============================] - 0s 11ms/step - loss: 0.6499 - accuracy: 1.0000
# Epoch 151/300
# 1/1 [==============================] - 0s 12ms/step - loss: 0.6495 - accuracy: 1.0000
# Epoch 152/300
# 1/1 [==============================] - 0s 11ms/step - loss: 0.6491 - accuracy: 1.0000
# Epoch 153/300
# 1/1 [==============================] - 0s 14ms/step - loss: 0.6486 - accuracy: 1.0000
# Epoch 154/300
# 1/1 [==============================] - 0s 11ms/step - loss: 0.6481 - accuracy: 1.0000
# Epoch 155/300
# 1/1 [==============================] - 0s 12ms/step - loss: 0.6476 - accuracy: 1.0000
# Epoch 156/300
# 1/1 [==============================] - 0s 10ms/step - loss: 0.6471 - accuracy: 1.0000
# Epoch 157/300
# 1/1 [==============================] - 0s 10ms/step - loss: 0.6467 - accuracy: 1.0000
# Epoch 158/300
# 1/1 [==============================] - 0s 9ms/step - loss: 0.6465 - accuracy: 1.0000
# Epoch 159/300
# 1/1 [==============================] - 0s 10ms/step - loss: 0.6461 - accuracy: 1.0000
# Epoch 160/300
# 1/1 [==============================] - 0s 10ms/step - loss: 0.6455 - accuracy: 1.0000
# Epoch 161/300
# 1/1 [==============================] - 0s 10ms/step - loss: 0.6450 - accuracy: 1.0000
# Epoch 162/300
# 1/1 [==============================] - 0s 10ms/step - loss: 0.6445 - accuracy: 1.0000
# Epoch 163/300
# 1/1 [==============================] - 0s 9ms/step - loss: 0.6441 - accuracy: 1.0000
# Epoch 164/300
# 1/1 [==============================] - 0s 10ms/step - loss: 0.6436 - accuracy: 1.0000
# Epoch 165/300
# 1/1 [==============================] - 0s 9ms/step - loss: 0.6431 - accuracy: 1.0000
# Epoch 166/300
# 1/1 [==============================] - 0s 10ms/step - loss: 0.6427 - accuracy: 1.0000
# Epoch 167/300
# 1/1 [==============================] - 0s 10ms/step - loss: 0.6423 - accuracy: 1.0000
# Epoch 168/300
# 1/1 [==============================] - 0s 10ms/step - loss: 0.6419 - accuracy: 1.0000
# Epoch 169/300
# 1/1 [==============================] - 0s 10ms/step - loss: 0.6413 - accuracy: 1.0000
# Epoch 170/300
# 1/1 [==============================] - 0s 11ms/step - loss: 0.6410 - accuracy: 1.0000
# Epoch 171/300
# 1/1 [==============================] - 0s 11ms/step - loss: 0.6406 - accuracy: 1.0000
# Epoch 172/300
# 1/1 [==============================] - 0s 10ms/step - loss: 0.6400 - accuracy: 1.0000
# Epoch 173/300
# 1/1 [==============================] - 0s 10ms/step - loss: 0.6396 - accuracy: 1.0000
# Epoch 174/300
# 1/1 [==============================] - 0s 10ms/step - loss: 0.6391 - accuracy: 1.0000
# Epoch 175/300
# 1/1 [==============================] - 0s 12ms/step - loss: 0.6387 - accuracy: 1.0000
# Epoch 176/300
# 1/1 [==============================] - 0s 10ms/step - loss: 0.6383 - accuracy: 1.0000
# Epoch 177/300
# 1/1 [==============================] - 0s 10ms/step - loss: 0.6379 - accuracy: 1.0000
# Epoch 178/300
# 1/1 [==============================] - 0s 10ms/step - loss: 0.6373 - accuracy: 1.0000
# Epoch 179/300
# 1/1 [==============================] - 0s 10ms/step - loss: 0.6368 - accuracy: 1.0000
# Epoch 180/300
# 1/1 [==============================] - 0s 9ms/step - loss: 0.6364 - accuracy: 1.0000
# Epoch 181/300
# 1/1 [==============================] - 0s 10ms/step - loss: 0.6360 - accuracy: 1.0000
# Epoch 182/300
# 1/1 [==============================] - 0s 10ms/step - loss: 0.6356 - accuracy: 1.0000
# Epoch 183/300
# 1/1 [==============================] - 0s 10ms/step - loss: 0.6351 - accuracy: 1.0000
# Epoch 184/300
# 1/1 [==============================] - 0s 10ms/step - loss: 0.6345 - accuracy: 1.0000
# Epoch 185/300
# 1/1 [==============================] - 0s 10ms/step - loss: 0.6340 - accuracy: 1.0000
# Epoch 186/300
# 1/1 [==============================] - 0s 10ms/step - loss: 0.6335 - accuracy: 1.0000
# Epoch 187/300
# 1/1 [==============================] - 0s 9ms/step - loss: 0.6331 - accuracy: 1.0000
# Epoch 188/300
# 1/1 [==============================] - 0s 9ms/step - loss: 0.6325 - accuracy: 1.0000
# Epoch 189/300
# 1/1 [==============================] - 0s 10ms/step - loss: 0.6321 - accuracy: 1.0000
# Epoch 190/300
# 1/1 [==============================] - 0s 10ms/step - loss: 0.6316 - accuracy: 1.0000
# Epoch 191/300
# 1/1 [==============================] - 0s 10ms/step - loss: 0.6312 - accuracy: 1.0000
# Epoch 192/300
# 1/1 [==============================] - 0s 10ms/step - loss: 0.6307 - accuracy: 1.0000
# Epoch 193/300
# 1/1 [==============================] - 0s 10ms/step - loss: 0.6300 - accuracy: 1.0000
# Epoch 194/300
# 1/1 [==============================] - 0s 10ms/step - loss: 0.6296 - accuracy: 1.0000
# Epoch 195/300
# 1/1 [==============================] - 0s 13ms/step - loss: 0.6292 - accuracy: 1.0000
# Epoch 196/300
# 1/1 [==============================] - 0s 13ms/step - loss: 0.6287 - accuracy: 1.0000
# Epoch 197/300
# 1/1 [==============================] - 0s 15ms/step - loss: 0.6282 - accuracy: 1.0000
# Epoch 198/300
# 1/1 [==============================] - 0s 12ms/step - loss: 0.6276 - accuracy: 1.0000
# Epoch 199/300
# 1/1 [==============================] - 0s 14ms/step - loss: 0.6271 - accuracy: 1.0000
# Epoch 200/300
# 1/1 [==============================] - 0s 13ms/step - loss: 0.6266 - accuracy: 1.0000
# Epoch 201/300
# 1/1 [==============================] - 0s 14ms/step - loss: 0.6261 - accuracy: 1.0000
# Epoch 202/300
# 1/1 [==============================] - 0s 16ms/step - loss: 0.6257 - accuracy: 1.0000
# Epoch 203/300
# 1/1 [==============================] - 0s 13ms/step - loss: 0.6252 - accuracy: 1.0000
# Epoch 204/300
# 1/1 [==============================] - 0s 13ms/step - loss: 0.6247 - accuracy: 1.0000
# Epoch 205/300
# 1/1 [==============================] - 0s 13ms/step - loss: 0.6241 - accuracy: 1.0000
# Epoch 206/300
# 1/1 [==============================] - 0s 12ms/step - loss: 0.6235 - accuracy: 1.0000
# Epoch 207/300
# 1/1 [==============================] - 0s 11ms/step - loss: 0.6230 - accuracy: 1.0000
# Epoch 208/300
# 1/1 [==============================] - 0s 12ms/step - loss: 0.6224 - accuracy: 1.0000
# Epoch 209/300
# 1/1 [==============================] - 0s 12ms/step - loss: 0.6219 - accuracy: 1.0000
# Epoch 210/300
# 1/1 [==============================] - 0s 13ms/step - loss: 0.6214 - accuracy: 1.0000
# Epoch 211/300
# 1/1 [==============================] - 0s 13ms/step - loss: 0.6208 - accuracy: 1.0000
# Epoch 212/300
# 1/1 [==============================] - 0s 13ms/step - loss: 0.6203 - accuracy: 1.0000
# Epoch 213/300
# 1/1 [==============================] - 0s 11ms/step - loss: 0.6198 - accuracy: 1.0000
# Epoch 214/300
# 1/1 [==============================] - 0s 12ms/step - loss: 0.6193 - accuracy: 1.0000
# Epoch 215/300
# 1/1 [==============================] - 0s 12ms/step - loss: 0.6187 - accuracy: 1.0000
# Epoch 216/300
# 1/1 [==============================] - 0s 13ms/step - loss: 0.6182 - accuracy: 1.0000
# Epoch 217/300
# 1/1 [==============================] - 0s 11ms/step - loss: 0.6176 - accuracy: 1.0000
# Epoch 218/300
# 1/1 [==============================] - 0s 14ms/step - loss: 0.6170 - accuracy: 1.0000
# Epoch 219/300
# 1/1 [==============================] - 0s 12ms/step - loss: 0.6165 - accuracy: 1.0000
# Epoch 220/300
# 1/1 [==============================] - 0s 12ms/step - loss: 0.6160 - accuracy: 1.0000
# Epoch 221/300
# 1/1 [==============================] - 0s 12ms/step - loss: 0.6155 - accuracy: 1.0000
# Epoch 222/300
# 1/1 [==============================] - 0s 12ms/step - loss: 0.6150 - accuracy: 1.0000
# Epoch 223/300
# 1/1 [==============================] - 0s 12ms/step - loss: 0.6144 - accuracy: 1.0000
# Epoch 224/300
# 1/1 [==============================] - 0s 12ms/step - loss: 0.6137 - accuracy: 1.0000
# Epoch 225/300
# 1/1 [==============================] - 0s 11ms/step - loss: 0.6131 - accuracy: 1.0000
# Epoch 226/300
# 1/1 [==============================] - 0s 12ms/step - loss: 0.6126 - accuracy: 1.0000
# Epoch 227/300
# 1/1 [==============================] - 0s 12ms/step - loss: 0.6121 - accuracy: 1.0000
# Epoch 228/300
# 1/1 [==============================] - 0s 12ms/step - loss: 0.6115 - accuracy: 1.0000
# Epoch 229/300
# 1/1 [==============================] - 0s 12ms/step - loss: 0.6109 - accuracy: 1.0000
# Epoch 230/300
# 1/1 [==============================] - 0s 12ms/step - loss: 0.6103 - accuracy: 1.0000
# Epoch 231/300
# 1/1 [==============================] - 0s 12ms/step - loss: 0.6099 - accuracy: 1.0000
# Epoch 232/300
# 1/1 [==============================] - 0s 11ms/step - loss: 0.6093 - accuracy: 1.0000
# Epoch 233/300
# 1/1 [==============================] - 0s 13ms/step - loss: 0.6086 - accuracy: 1.0000
# Epoch 234/300
# 1/1 [==============================] - 0s 12ms/step - loss: 0.6081 - accuracy: 1.0000
# Epoch 235/300
# 1/1 [==============================] - 0s 16ms/step - loss: 0.6075 - accuracy: 1.0000
# Epoch 236/300
# 1/1 [==============================] - 0s 13ms/step - loss: 0.6069 - accuracy: 1.0000
# Epoch 237/300
# 1/1 [==============================] - 0s 13ms/step - loss: 0.6062 - accuracy: 1.0000
# Epoch 238/300
# 1/1 [==============================] - 0s 12ms/step - loss: 0.6057 - accuracy: 1.0000
# Epoch 239/300
# 1/1 [==============================] - 0s 14ms/step - loss: 0.6050 - accuracy: 1.0000
# Epoch 240/300
# 1/1 [==============================] - 0s 12ms/step - loss: 0.6044 - accuracy: 1.0000
# Epoch 241/300
# 1/1 [==============================] - 0s 12ms/step - loss: 0.6039 - accuracy: 1.0000
# Epoch 242/300
# 1/1 [==============================] - 0s 13ms/step - loss: 0.6032 - accuracy: 1.0000
# Epoch 243/300
# 1/1 [==============================] - 0s 13ms/step - loss: 0.6026 - accuracy: 1.0000
# Epoch 244/300
# 1/1 [==============================] - 0s 10ms/step - loss: 0.6022 - accuracy: 1.0000
# Epoch 245/300
# 1/1 [==============================] - 0s 12ms/step - loss: 0.6015 - accuracy: 1.0000
# Epoch 246/300
# 1/1 [==============================] - 0s 12ms/step - loss: 0.6007 - accuracy: 1.0000
# Epoch 247/300
# 1/1 [==============================] - 0s 12ms/step - loss: 0.6002 - accuracy: 1.0000
# Epoch 248/300
# 1/1 [==============================] - 0s 12ms/step - loss: 0.5995 - accuracy: 1.0000
# Epoch 249/300
# 1/1 [==============================] - 0s 13ms/step - loss: 0.5989 - accuracy: 1.0000
# Epoch 250/300
# 1/1 [==============================] - 0s 12ms/step - loss: 0.5982 - accuracy: 1.0000
# Epoch 251/300
# 1/1 [==============================] - 0s 12ms/step - loss: 0.5976 - accuracy: 1.0000
# Epoch 252/300
# 1/1 [==============================] - 0s 12ms/step - loss: 0.5969 - accuracy: 1.0000
# Epoch 253/300
# 1/1 [==============================] - 0s 12ms/step - loss: 0.5963 - accuracy: 1.0000
# Epoch 254/300
# 1/1 [==============================] - 0s 11ms/step - loss: 0.5957 - accuracy: 1.0000
# Epoch 255/300
# 1/1 [==============================] - 0s 11ms/step - loss: 0.5950 - accuracy: 1.0000
# Epoch 256/300
# 1/1 [==============================] - 0s 10ms/step - loss: 0.5943 - accuracy: 1.0000
# Epoch 257/300
# 1/1 [==============================] - 0s 10ms/step - loss: 0.5937 - accuracy: 1.0000
# Epoch 258/300
# 1/1 [==============================] - 0s 9ms/step - loss: 0.5931 - accuracy: 1.0000
# Epoch 259/300
# 1/1 [==============================] - 0s 10ms/step - loss: 0.5925 - accuracy: 1.0000
# Epoch 260/300
# 1/1 [==============================] - 0s 10ms/step - loss: 0.5917 - accuracy: 1.0000
# Epoch 261/300
# 1/1 [==============================] - 0s 10ms/step - loss: 0.5911 - accuracy: 1.0000
# Epoch 262/300
# 1/1 [==============================] - 0s 9ms/step - loss: 0.5904 - accuracy: 1.0000
# Epoch 263/300
# 1/1 [==============================] - 0s 9ms/step - loss: 0.5898 - accuracy: 1.0000
# Epoch 264/300
# 1/1 [==============================] - 0s 10ms/step - loss: 0.5891 - accuracy: 1.0000
# Epoch 265/300
# 1/1 [==============================] - 0s 10ms/step - loss: 0.5885 - accuracy: 1.0000
# Epoch 266/300
# 1/1 [==============================] - 0s 10ms/step - loss: 0.5878 - accuracy: 1.0000
# Epoch 267/300
# 1/1 [==============================] - 0s 13ms/step - loss: 0.5871 - accuracy: 1.0000
# Epoch 268/300
# 1/1 [==============================] - 0s 11ms/step - loss: 0.5864 - accuracy: 1.0000
# Epoch 269/300
# 1/1 [==============================] - 0s 10ms/step - loss: 0.5857 - accuracy: 1.0000
# Epoch 270/300
# 1/1 [==============================] - 0s 10ms/step - loss: 0.5850 - accuracy: 1.0000
# Epoch 271/300
# 1/1 [==============================] - 0s 10ms/step - loss: 0.5844 - accuracy: 1.0000
# Epoch 272/300
# 1/1 [==============================] - 0s 10ms/step - loss: 0.5837 - accuracy: 1.0000
# Epoch 273/300
# 1/1 [==============================] - 0s 10ms/step - loss: 0.5830 - accuracy: 1.0000
# Epoch 274/300
# 1/1 [==============================] - 0s 9ms/step - loss: 0.5823 - accuracy: 1.0000
# Epoch 275/300
# 1/1 [==============================] - 0s 9ms/step - loss: 0.5816 - accuracy: 1.0000
# Epoch 276/300
# 1/1 [==============================] - 0s 10ms/step - loss: 0.5809 - accuracy: 1.0000
# Epoch 277/300
# 1/1 [==============================] - 0s 11ms/step - loss: 0.5802 - accuracy: 1.0000
# Epoch 278/300
# 1/1 [==============================] - 0s 10ms/step - loss: 0.5795 - accuracy: 1.0000
# Epoch 279/300
# 1/1 [==============================] - 0s 10ms/step - loss: 0.5787 - accuracy: 1.0000
# Epoch 280/300
# 1/1 [==============================] - 0s 10ms/step - loss: 0.5780 - accuracy: 1.0000
# Epoch 281/300
# 1/1 [==============================] - 0s 12ms/step - loss: 0.5773 - accuracy: 1.0000
# Epoch 282/300
# 1/1 [==============================] - 0s 12ms/step - loss: 0.5766 - accuracy: 1.0000
# Epoch 283/300
# 1/1 [==============================] - 0s 11ms/step - loss: 0.5759 - accuracy: 1.0000
# Epoch 284/300
# 1/1 [==============================] - 0s 9ms/step - loss: 0.5751 - accuracy: 1.0000
# Epoch 285/300
# 1/1 [==============================] - 0s 11ms/step - loss: 0.5744 - accuracy: 1.0000
# Epoch 286/300
# 1/1 [==============================] - 0s 10ms/step - loss: 0.5737 - accuracy: 1.0000
# Epoch 287/300
# 1/1 [==============================] - 0s 10ms/step - loss: 0.5731 - accuracy: 1.0000
# Epoch 288/300
# 1/1 [==============================] - 0s 10ms/step - loss: 0.5724 - accuracy: 1.0000
# Epoch 289/300
# 1/1 [==============================] - 0s 9ms/step - loss: 0.5716 - accuracy: 1.0000
# Epoch 290/300
# 1/1 [==============================] - 0s 9ms/step - loss: 0.5708 - accuracy: 1.0000
# Epoch 291/300
# 1/1 [==============================] - 0s 9ms/step - loss: 0.5700 - accuracy: 1.0000
# Epoch 292/300
# 1/1 [==============================] - 0s 9ms/step - loss: 0.5694 - accuracy: 1.0000
# Epoch 293/300
# 1/1 [==============================] - 0s 10ms/step - loss: 0.5686 - accuracy: 1.0000
# Epoch 294/300
# 1/1 [==============================] - 0s 10ms/step - loss: 0.5678 - accuracy: 1.0000
# Epoch 295/300
# 1/1 [==============================] - 0s 9ms/step - loss: 0.5671 - accuracy: 1.0000
# Epoch 296/300
# 1/1 [==============================] - 0s 11ms/step - loss: 0.5664 - accuracy: 1.0000
# Epoch 297/300
# 1/1 [==============================] - 0s 10ms/step - loss: 0.5656 - accuracy: 1.0000
# Epoch 298/300
# 1/1 [==============================] - 0s 10ms/step - loss: 0.5647 - accuracy: 1.0000
# Epoch 299/300
# 1/1 [==============================] - 0s 10ms/step - loss: 0.5640 - accuracy: 1.0000
# Epoch 300/300
# 1/1 [==============================] - 0s 9ms/step - loss: 0.5634 - accuracy: 1.0000
# 1/1 [==============================] - 0s 127ms/step
# [[0.]
#  [1.]
#  [1.]
#  [0.]]

# %% [markdown]
# The code above is Question 6
